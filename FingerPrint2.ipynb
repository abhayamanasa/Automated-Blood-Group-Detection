# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
import os
from PIL import Image

# Check if CUDA is available, otherwise use CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Define the transformation for the input image
data_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load the dataset
data_dir = r'D:\Mini\archive1\dataset_blood_group'
image_dataset = datasets.ImageFolder(data_dir, transform=data_transform)

# Split the dataset into training and validation sets (80/20 split)
train_size = int(0.8 * len(image_dataset))
val_size = len(image_dataset) - train_size
train_dataset, val_dataset = random_split(image_dataset, [train_size, val_size])

# Optimize data loading
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=8, pin_memory=True)

dataloaders = {'train': train_loader, 'val': val_loader}

# Define a simpler CNN model
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(64 * 56 * 56, 512)
        self.fc2 = nn.Linear(512, 8)  # 8 classes for the 8 blood groups

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64 * 56 * 56)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

model = SimpleCNN().to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Training the model
num_epochs = 25
for epoch in range(num_epochs):
    print(f'\nEpoch {epoch+1}/{num_epochs}')
    
    for phase in ['train', 'val']:
        if phase == 'train':
            model.train()
            print("Training...")
        else:
            model.eval()
            print("Validating...")

        running_loss = 0.0
        running_corrects = 0

        for inputs, labels in dataloaders[phase]:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            print(f"Batch done: Loss: {loss.item():.4f}")

        epoch_loss = running_loss / len(dataloaders[phase].dataset)
        epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

        print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

# Save the trained model
torch.save(model.state_dict(), 'fingerprint_blood_group_model.pth')
# Out:
# Using device: cpu
#
# Epoch 1/25
# Training...
# Batch done: Loss: 2.0779
# Batch done: Loss: 2.1551
# Batch done: Loss: 2.2045
# Batch done: Loss: 2.0983
# Batch done: Loss: 2.0965
# Batch done: Loss: 2.0706
# Batch done: Loss: 2.0933
# Batch done: Loss: 2.0759
# Batch done: Loss: 2.0420
# Batch done: Loss: 1.9961
# Train Loss: 2.0913 Acc: 0.1223
# Validating...
# Batch done: Loss: 2.0821
# Batch done: Loss: 2.0483
# Batch done: Loss: 2.1489
# Val Loss: 2.0819 Acc: 0.0625
#
# Epoch 2/25
# Training...
# Batch done: Loss: 2.0771
# Batch done: Loss: 2.0066
# Batch done: Loss: 2.0555
# Batch done: Loss: 1.8470
# Batch done: Loss: 1.9904
# Batch done: Loss: 1.8727
# Batch done: Loss: 1.8523
# Batch done: Loss: 1.8363
# Batch done: Loss: 1.7924
# Batch done: Loss: 1.8130
# Train Loss: 1.9147 Acc: 0.2508
# Validating...
# Batch done: Loss: 1.8029
# Batch done: Loss: 1.8628
# Batch done: Loss: 1.9379
# Val Loss: 1.8539 Acc: 0.2375
#
# Epoch 3/25
# Training...
# Batch done: Loss: 1.8614
# Batch done: Loss: 1.7794
# Batch done: Loss: 1.6675
# Batch done: Loss: 1.7639
# Batch done: Loss: 1.6833
# Batch done: Loss: 1.7825
# Batch done: Loss: 1.6443
# Batch done: Loss: 1.5948
# Batch done: Loss: 1.6265
# Batch done: Loss: 1.4836
# Train Loss: 1.6894 Acc: 0.3699
# Validating...
# Batch done: Loss: 1.5286
# Batch done: Loss: 1.7545
# Batch done: Loss: 1.6321
# Val Loss: 1.6397 Acc: 0.2875
#
# Epoch 4/25
# Training...
# Batch done: Loss: 1.3207
# Batch done: Loss: 1.4352
# Batch done: Loss: 1.6102
# Batch done: Loss: 1.4597
# Batch done: Loss: 1.8194
# Batch done: Loss: 1.3910
# Batch done: Loss: 1.5354
# Batch done: Loss: 1.5788
# Batch done: Loss: 1.4210
# Batch done: Loss: 1.2953
# Train Loss: 1.4873 Acc: 0.4702
# Validating...
# Batch done: Loss: 1.4217
# Batch done: Loss: 1.6145
# Batch done: Loss: 1.4940
# Val Loss: 1.5133 Acc: 0.3125
#
# Epoch 5/25
# Training...
# Batch done: Loss: 1.3399
# Batch done: Loss: 1.2817
# Batch done: Loss: 1.1947
# Batch done: Loss: 1.3469
# Batch done: Loss: 1.3544
# Batch done: Loss: 1.2975
# Batch done: Loss: 1.1405
# Batch done: Loss: 1.2314
# Batch done: Loss: 1.3878
# Batch done: Loss: 1.0913
# Train Loss: 1.2672 Acc: 0.5580
# Validating...
# Batch done: Loss: 1.2322
# Batch done: Loss: 1.5823
# Batch done: Loss: 1.3368
# Val Loss: 1.3931 Acc: 0.4500
#
# Epoch 6/25
# Training...
# Batch done: Loss: 1.1242
# Batch done: Loss: 1.1764
# Batch done: Loss: 1.1533
# Batch done: Loss: 1.1127
# Batch done: Loss: 0.9735
# Batch done: Loss: 1.0598
# Batch done: Loss: 1.1901
# Batch done: Loss: 1.0537
# Batch done: Loss: 1.0001
# Batch done: Loss: 1.0206
# Train Loss: 1.0866 Acc: 0.6301
# Validating...
# Batch done: Loss: 1.3986
# Batch done: Loss: 1.8049
# Batch done: Loss: 1.3656
# Val Loss: 1.5545 Acc: 0.3750
#
# Epoch 7/25
# Training...
# Batch done: Loss: 1.0890
# Batch done: Loss: 0.9422
# Batch done: Loss: 0.8738
# Batch done: Loss: 0.9697
# Batch done: Loss: 0.9109
# Batch done: Loss: 0.8569
# Batch done: Loss: 1.0556
# Batch done: Loss: 1.3950
# Batch done: Loss: 0.8534
# Batch done: Loss: 0.7796
# Train Loss: 0.9732 Acc: 0.6426
# Validating...
# Batch done: Loss: 1.0590
# Batch done: Loss: 1.5600
# Batch done: Loss: 1.1472
# Val Loss: 1.2770 Acc: 0.4875
#
# Epoch 8/25
# Training...
# Batch done: Loss: 0.7660
# Batch done: Loss: 0.9022
# Batch done: Loss: 0.9614
# Batch done: Loss: 0.9164
# Batch done: Loss: 0.6343
# Batch done: Loss: 0.7333
# Batch done: Loss: 0.7751
# Batch done: Loss: 1.0801
# Batch done: Loss: 0.7655
# Batch done: Loss: 0.8247
# Train Loss: 0.8359 Acc: 0.7085
# Validating...
# Batch done: Loss: 0.9653
# Batch done: Loss: 1.2841
# Batch done: Loss: 0.9756
# Val Loss: 1.0949 Acc: 0.5625
#
# Epoch 9/25
# Training...
# Batch done: Loss: 0.5467
# Batch done: Loss: 0.7090
# Batch done: Loss: 0.7127
# Batch done: Loss: 0.7647
# Batch done: Loss: 0.7023
# Batch done: Loss: 0.5057
# Batch done: Loss: 0.6743
# Batch done: Loss: 0.6416
# Batch done: Loss: 0.7363
# Batch done: Loss: 0.4989
# Train Loss: 0.6497 Acc: 0.8213
# Validating...
# Batch done: Loss: 0.9814
# Batch done: Loss: 1.2524
# Batch done: Loss: 0.8733
# Val Loss: 1.0682 Acc: 0.5750
#
# Epoch 10/25
# Training...
# Batch done: Loss: 0.4731
# Batch done: Loss: 0.6479
# Batch done: Loss: 0.5042
# Batch done: Loss: 0.4473
# Batch done: Loss: 0.4050
# Batch done: Loss: 0.3868
# Batch done: Loss: 0.3636
# Batch done: Loss: 0.4542
# Batch done: Loss: 0.5445
# Batch done: Loss: 0.3521
# Train Loss: 0.4582 Acc: 0.9185
# Validating...
# Batch done: Loss: 0.7856
# Batch done: Loss: 1.1486
# Batch done: Loss: 0.8258
# Val Loss: 0.9388 Acc: 0.5750
#
# Epoch 11/25
# Training...
# Batch done: Loss: 0.2835
# Batch done: Loss: 0.5415
# Batch done: Loss: 0.3886
# Batch done: Loss: 0.2276
# Batch done: Loss: 0.2487
# Batch done: Loss: 0.4856
# Batch done: Loss: 0.3051
# Batch done: Loss: 0.3572
# Batch done: Loss: 0.4284
# Batch done: Loss: 0.2881
# Train Loss: 0.3556 Acc: 0.9122
# Validating...
# Batch done: Loss: 0.7118
# Batch done: Loss: 1.0706
# Batch done: Loss: 0.6523
# Val Loss: 0.8434 Acc: 0.6500
#
# Epoch 12/25
# Training...
# Batch done: Loss: 0.3514
# Batch done: Loss: 0.2408
# Batch done: Loss: 0.3093
# Batch done: Loss: 0.3006
# Batch done: Loss: 0.2221
# Batch done: Loss: 0.2243
# Batch done: Loss: 0.2000
# Batch done: Loss: 0.2707
# Batch done: Loss: 0.1966
# Batch done: Loss: 0.1966
# Train Loss: 0.2514 Acc: 0.9592
# Validating...
# Batch done: Loss: 0.6056
# Batch done: Loss: 1.0234
# Batch done: Loss: 0.7558
# Val Loss: 0.8027 Acc: 0.6375
#
# Epoch 13/25
# Training...
# Batch done: Loss: 0.1196
# Batch done: Loss: 0.3120
# Batch done: Loss: 0.2378
# Batch done: Loss: 0.1875
# Batch done: Loss: 0.1944
# Batch done: Loss: 0.1052
# Batch done: Loss: 0.1510
# Batch done: Loss: 0.1975
# Batch done: Loss: 0.1807
# Batch done: Loss: 0.2277
# Train Loss: 0.1912 Acc: 0.9812
# Validating...
# Batch done: Loss: 0.6171
# Batch done: Loss: 0.8842
# Batch done: Loss: 0.4905
# Val Loss: 0.6986 Acc: 0.6625
#
# Epoch 14/25
# Training...
# Batch done: Loss: 0.1559
# Batch done: Loss: 0.0833
# Batch done: Loss: 0.2014
# Batch done: Loss: 0.2773
# Batch done: Loss: 0.1969
# Batch done: Loss: 0.0966
# Batch done: Loss: 0.1192
# Batch done: Loss: 0.0921
# Batch done: Loss: 0.1159
# Batch done: Loss: 0.2041
# Train Loss: 0.1541 Acc: 0.9843
# Validating...
# Batch done: Loss: 0.7467
# Batch done: Loss: 0.9417
# Batch done: Loss: 0.5276
# Val Loss: 0.7809 Acc: 0.6500
#
# Epoch 15/25
# Training...
# Batch done: Loss: 0.1075
# Batch done: Loss: 0.1047
# Batch done: Loss: 0.1010
# Batch done: Loss: 0.1086
# Batch done: Loss: 0.1158
# Batch done: Loss: 0.0824
# Batch done: Loss: 0.1413
# Batch done: Loss: 0.1046
# Batch done: Loss: 0.0782
# Batch done: Loss: 0.0687
# Train Loss: 0.1014 Acc: 0.9969
# Validating...
# Batch done: Loss: 0.5988
# Batch done: Loss: 0.9024
# Batch done: Loss: 0.4757
# Val Loss: 0.6956 Acc: 0.7250
#
# Epoch 16/25
# Training...
# Batch done: Loss: 0.0527
# Batch done: Loss: 0.1001
# Batch done: Loss: 0.1083
# Batch done: Loss: 0.0844
# Batch done: Loss: 0.0785
# Batch done: Loss: 0.0922
# Batch done: Loss: 0.0667
# Batch done: Loss: 0.0518
# Batch done: Loss: 0.0636
# Batch done: Loss: 0.0580
# Train Loss: 0.0757 Acc: 0.9969
# Validating...
# Batch done: Loss: 0.6130
# Batch done: Loss: 0.8730
# Batch done: Loss: 0.4736
# Val Loss: 0.6891 Acc: 0.7250
#
# Epoch 17/25
# Training...
# Batch done: Loss: 0.0710
# Batch done: Loss: 0.0476
# Batch done: Loss: 0.0472
# Batch done: Loss: 0.0539
# Batch done: Loss: 0.0489
# Batch done: Loss: 0.0459
# Batch done: Loss: 0.0718
# Batch done: Loss: 0.0630
# Batch done: Loss: 0.0376
# Batch done: Loss: 0.0620
# Train Loss: 0.0549 Acc: 1.0000
# Validating...
# Batch done: Loss: 0.5272
# Batch done: Loss: 0.7866
# Batch done: Loss: 0.4299
# Val Loss: 0.6115 Acc: 0.7000
#
# Epoch 18/25
# Training...
# Batch done: Loss: 0.0380
# Batch done: Loss: 0.0441
# Batch done: Loss: 0.0248
# Batch done: Loss: 0.0302
# Batch done: Loss: 0.0581
# Batch done: Loss: 0.0343
# Batch done: Loss: 0.0476
# Batch done: Loss: 0.0266
# Batch done: Loss: 0.0425
# Batch done: Loss: 0.0380
# Train Loss: 0.0384 Acc: 1.0000
# Validating...
# Batch done: Loss: 0.5002
# Batch done: Loss: 0.7916
# Batch done: Loss: 0.4790
# Val Loss: 0.6125 Acc: 0.7125
#
# Epoch 19/25
# Training...
# Batch done: Loss: 0.0326
# Batch done: Loss: 0.0329
# Batch done: Loss: 0.0364
# Batch done: Loss: 0.0463
# Batch done: Loss: 0.0333
# Batch done: Loss: 0.0329
# Batch done: Loss: 0.0266
# Batch done: Loss: 0.0303
# Batch done: Loss: 0.0168
# Batch done: Loss: 0.0391
# Train Loss: 0.0327 Acc: 1.0000
# Validating...
# Batch done: Loss: 0.5049
# Batch done: Loss: 0.7811
# Batch done: Loss: 0.3426
# Val Loss: 0.5829 Acc: 0.7375
#
# Epoch 20/25
# Training...
# Batch done: Loss: 0.0175
# Batch done: Loss: 0.0324
# Batch done: Loss: 0.0167
# Batch done: Loss: 0.0213
# Batch done: Loss: 0.0273
# Batch done: Loss: 0.0349
# Batch done: Loss: 0.0294
# Batch done: Loss: 0.0219
# Batch done: Loss: 0.0351
# Batch done: Loss: 0.0264
# Train Loss: 0.0263 Acc: 1.0000
# Validating...
# Batch done: Loss: 0.4936
# Batch done: Loss: 0.7833
# Batch done: Loss: 0.4824
# Val Loss: 0.6073 Acc: 0.6875
#
# Epoch 21/25
# Training...
# Batch done: Loss: 0.0200
# Batch done: Loss: 0.0226
# Batch done: Loss: 0.0216
# Batch done: Loss: 0.0197
# Batch done: Loss: 0.0209
# Batch done: Loss: 0.0280
# Batch done: Loss: 0.0136
# Batch done: Loss: 0.0260
# Batch done: Loss: 0.0234
# Batch done: Loss: 0.0255
# Train Loss: 0.0221 Acc: 1.0000
# Validating...
# Batch done: Loss: 0.4895
# Batch done: Loss: 0.7698
# Batch done: Loss: 0.4051
# Val Loss: 0.5847 Acc: 0.7125
#
# Epoch 22/25
# Training...
# Batch done: Loss: 0.0202
# Batch done: Loss: 0.0248
# Batch done: Loss: 0.0135
# Batch done: Loss: 0.0216
# Batch done: Loss: 0.0204
# Batch done: Loss: 0.0194
# Batch done: Loss: 0.0167
# Batch done: Loss: 0.0187
# Batch done: Loss: 0.0210
# Batch done: Loss: 0.0185
# Train Loss: 0.0195 Acc: 1.0000
# Validating...
# Batch done: Loss: 0.5059
# Batch done: Loss: 0.7776
# Batch done: Loss: 0.4300
# Val Loss: 0.5994 Acc: 0.6875
#
# Epoch 23/25
# Training...
# Batch done: Loss: 0.0149
# Batch done: Loss: 0.0165
# Batch done: Loss: 0.0197
# Batch done: Loss: 0.0171
# Batch done: Loss: 0.0178
# Batch done: Loss: 0.0170
# Batch done: Loss: 0.0166
# Batch done: Loss: 0.0126
# Batch done: Loss: 0.0221
# Batch done: Loss: 0.0180
# Train Loss: 0.0172 Acc: 1.0000
# Validating...
# Batch done: Loss: 0.5042
# Batch done: Loss: 0.7830
# Batch done: Loss: 0.4277
# Val Loss: 0.6004 Acc: 0.7125
#
# Epoch 24/25
# Training...
# Batch done: Loss: 0.0241
# Batch done: Loss: 0.0129
# Batch done: Loss: 0.0230
# Batch done: Loss: 0.0183
# Batch done: Loss: 0.0132
# Batch done: Loss: 0.0164
# Batch done: Loss: 0.0138
# Batch done: Loss: 0.0108
# Batch done: Loss: 0.0132
# Batch done: Loss: 0.0098
# Train Loss: 0.0156 Acc: 1.0000
# Validating...
# Batch done: Loss: 0.4945
# Batch done: Loss: 0.7749
# Batch done: Loss: 0.4018
# Val Loss: 0.5881 Acc: 0.7125
#
# Epoch 25/25
# Training...
# Batch done: Loss: 0.0109
# Batch done: Loss: 0.0114
# Batch done: Loss: 0.0096
# Batch done: Loss: 0.0170
# Batch done: Loss: 0.0145
# Batch done: Loss: 0.0132
# Batch done: Loss: 0.0161
# Batch done: Loss: 0.0157
# Batch done: Loss: 0.0154
# Batch done: Loss: 0.0153
# Train Loss: 0.0139 Acc: 1.0000
# Validating...
# Batch done: Loss: 0.4983
# Batch done: Loss: 0.7897
# Batch done: Loss: 0.4314
# Val Loss: 0.6015 Acc: 0.6875

# %%
from tkinter import Tk, filedialog, messagebox

# %%
# Prediction function
def predict_image(image_path, model):
    image = Image.open(image_path).convert('RGB')
    image = data_transform(image)
    image = image.unsqueeze(0).to(device)

    model.eval()
    with torch.no_grad():
        outputs = model(image)
        _, preds = torch.max(outputs, 1)
    
    return preds.item()

# Function to upload image and predict blood group
def upload_and_predict():
    root = Tk()
    root.withdraw()  # Hide the root window
    file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.bmp;*.jpg;*.jpeg;*.png")])
    
    if not file_path:
        messagebox.showinfo("Info", "No file selected")
        return
    
    predicted_class = predict_image(file_path, model)
    blood_groups = ['A+', 'A-', 'AB+', 'AB-', 'B+', 'B-', 'O+', 'O-']
    result = f'The predicted blood group is: {blood_groups[predicted_class]}'
    messagebox.showinfo("Prediction Result", result)

# Call the upload and predict function
upload_and_predict()
